# %%
pip install aiohttp
# Out:
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.4 MB/s eta 0:00:00 0:00:01
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp) (22.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp) (2.1.1)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.0/264.0 kB 34.6 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp) (3.4)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 yarl-1.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from key import key
import time
import asyncio
import aiohttp
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import json
import csv
import requests

video_url_string = 'https://www.youtube.com/watch?v='
url = "https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id={}&key={}"
results = []

start_time = time.time()

def get_videos_ids(url, session):
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36"}
    req = Request(url, headers=headers)
    response = urlopen(req)
    soup = BeautifulSoup(urlopen(req), features="html.parser")
    # channelID from metadata
    channel_id = soup.find_all('meta', {'itemprop' : 'channelId'})[0].attrs['content']
     # count set to 25, api will fetch javascript for those videos throug API
    channel_id_url = f"https://www.googleapis.com/youtube/v3/search?key={key}&channelId={channel_id}&part=snippet,id&order=date&maxResults=25"
    # closes the connection
    response.close() 
    # open the connection through google api
    #req1 = Request(channel_id_url, headers=headers)
    #response1 = urlopen(req1)
    response1 = requests.get(channel_id_url)
    # converts the resonse into json
    response_data = response1.json()
    print(response_data)
    # data is in dict format & fetch unique videoId of each video from the channel page.
    videos_ids = []
    for item in response_data['items']:
        for k in (item['id']).keys():
            if k == 'videoId':
                videos_ids.append(item['id']['videoId'])

    return videos_ids

# %%
get_videos_ids('https://www.youtube.com/@SimplilearnOfficial/videos', 'ok')
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'EoUid8SdPvKbOdhnAPA8PNsP6pI', 'nextPageToken': 'CBkQAA', 'regionCode': 'IN', 'pageInfo': {'totalResults': 5432, 'resultsPerPage': 25}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'qKwE-Ym5Is3xa6v2uph4nWEJdEI', 'id': {'kind': 'youtube#video', 'videoId': 'aKBqUbQ0jX8'}, 'snippet': {'publishedAt': '2023-03-12T14:30:00Z', 'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg', 'title': 'Web Developer vs Web Designer | Difference Between Web Designer And Web Developer | Simplilearn', 'description': 'Post Graduate Program In Full Stack Web Development: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aKBqUbQ0jX8/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/aKBqUbQ0jX8/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/aKBqUbQ0jX8/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Simplilearn', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-12T14:30:00Z'}}, {'kind': 'youtube#searchResult', 'etag': 'x7GruMRKa0VvyC5_Zqp0fRamQVU', 'id': {'kind': 'youtube#video', 'videoId': 'uXjfWELEVhw'}, 'snippet': {'publishedAt': '2023-03-12T13:22:47Z', 'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg', 'title': '🔥Digital Marketing Full Course For Beginners | Digital Marketing Complete Course | Simplilearn', 'description': 'Digital Marketing Specialist Program: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uXjfWELEVhw/default_live.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/uXjfWELEVhw/mqdefault_live.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/uXjfWELEVhw/hqdefault_live.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Simplilearn', 'liveBroadcastContent': 'live', 'publishTime': '2023-03-12T13:22:47Z'}}, {'kind': 'youtube#searchResult', 'etag': 'JHcZwR2eiaxPn7Xf906WMSoVKws', 'id': {'kind': 'youtube#video', 'videoId': 'c-AbYL36aQ8'}, 'snippet': {'publishedAt': '2023-03-12T09:32:45Z', 'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg', 'title': '🔥Front End Full Course | Front End Development Tutorial | Front End Development Course | Simplilearn', 'description': 'Full Stack Developer - MEAN Stack: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/c-AbYL36aQ8/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/c-AbYL36aQ8/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/c-AbYL36aQ8/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Simplilearn', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-12T09:32:45Z'}}, {'kind': 'youtube#searchResult', 'etag': '7A9a5N5OAICM-KWHAcNbPmAX1Mc', 'id': {'kind': 'youtube#video', 'videoId': 'WhPBRt7da7w'}, 'snippet': {'publishedAt': '2023-03-12T07:30:13Z', 'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg', 'title': '🔥🔥 Caltech Data Analytics Bootcamp By Simplilearn 😍 #Shorts #DataAnalytics | Simplilearn', 'description': 'Caltech Data Analytics Bootcamp (US Only): ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WhPBRt7da7w/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/WhPBRt7da7w/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/WhPBRt7da7w/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Simplilearn', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-12T07:30:13Z'}}, {'kind': 'youtube#searchResult', 'etag': 'M_7-cYVg5rgxlsp_O4Cm7ijaYIw', 'id': {'kind': 'youtube#video', 'videoId': '3exVDXi4j4k'}, 'snippet': {'publishedAt': '2023-03-11T14:30:00Z', 'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg', 'title': 'YouTube Ads Tutorial 2023 | Complete YouTube Ads Course in 1 Hour | Simplilearn', 'description': 'Explore Digital Marketing Certification Program by Simplilearn: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3exVDXi4j4k/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.c ...
# ['aKBqUbQ0jX8',
#  'uXjfWELEVhw',
#  'c-AbYL36aQ8',
#  'WhPBRt7da7w',
#  '3exVDXi4j4k',
#  'Ge7YU80dIeU',
#  'kuVEl3eupnw',
#  'xQTAXj5Gcpw',
#  'IAfKYoyYwcQ',
#  'xRhqKLwYEfo',
#  'A9igUa20gcw',
#  'ONBmh61NoHw',
#  'N4WDpy-va1o',
#  'HbIMwaWvT6g',
#  'w0f1FcWVrjU',
#  'Be_CSlzqBlE',
#  'BAgqBaPSobQ',
#  'zek0EtE4FoM',
#  'ufYGUHaa7zs',
#  'AuFL93J-35E',
#  'kN2T2oc-Mew',
#  'O4i8eQ_RiR8',
#  'EcK3Ud9rXVA',
#  'xWDKF_VqpyM',
#  'fgecJANBjOk']

# %%
import urllib.request as urlRequest
import urllib.parse as urlParse

url = 'https://www.youtube.com/@SimplilearnOfficial/videos'
# pretend to be a chrome 47 browser on a windows 10 machine
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36"}
req = urlRequest.Request(url, headers = headers)
# open the url
raw_data = urlRequest.urlopen(req)
# get the source code
soup = BeautifulSoup(raw_data, features="html.parser")
# channelID from metadata
channel_id = soup.find_all('meta', {'itemprop' : 'channelId'})[0].attrs['content']
 # count set to 25, api will fetch javascript for those videos throug API
channel_id_url = f"https://www.googleapis.com/youtube/v3/search?key={key}&channelId={channel_id}&part=snippet,id&order=date&maxResults=25"

raw_response_data = urlRequest.urlopen(channel_id_url)

raw_response_data.json()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[16], line 17
#      14  # count set to 25, api will fetch javascript for those videos throug API
#      15 channel_id_url = f"https://www.googleapis.com/youtube/v3/search?key={key}&channelId={channel_id}&part=snippet,id&order=date&maxResults=25"
# ---> 17 raw_response_data = urlRequest.urlopen(channel_id_url)
#      19 raw_response_data.json()
#
# File /opt/conda/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /opt/conda/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /opt/conda/lib/python3.10/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /opt/conda/lib/python3.10/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /opt/conda/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /opt/conda/lib/python3.10/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
sourceCode
# Out:
# b'<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" system-icons typography typography-spacing darker-dark-theme darker-dark-theme-deprecate><head><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="AlgsH67ctYlMR3JYAxEnGfvsoFo41AMqAg6wRHHXOpWAfD54ZCfTPBclxnFT4Gc8IUX4pq6Xfo0esDuOt+WH3wIAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2ODA2NTI3OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script nonce="HZFHEKwD8BfPfqExiBYe0Q">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};\nwindow.ytcfg.set(\'EMERGENCY_BASE_URL\', \'\\/error_204?t\\x3djserror\\x26level\\x3dERROR\\x26client.name\\x3d1\\x26client.version\\x3d2.20230309.08.00\');</script><script nonce="HZFHEKwD8BfPfqExiBYe0Q">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber))err["columnNumber"]=columnNumber}var message=String(err.message);if(!err.message||message in window.unhandledErrorMessages||window.unhandledErrorCount>=5)return;window.unhandledErrorCount+=1;window.unhandledErrorMessages[message]=true;var img=new Image;window.emergencyTimeoutImg=img;img.onload=img.onerror=function(){delete window.emergencyTimeoutImg};\nvar combinedLineAndColumn=err.lineNumber;if(!isNaN(err["columnNumber"]))combinedLineAndColumn+=":"+err["columnNumber"];var stack=err.stack||"";var values={"msg":message,"type":err.name,"client.params":"unhandled window error","file":err.fileName,"line":combinedLineAndColumn,"stack":stack.substr(0,500)};var thirdPartyScript=!err.fileName||err.fileName==="<anonymous>"||stack.indexOf("extension://")>=0;var replaced=stack.replace(/https:\\/\\/www.youtube.com\\//g,"");if(replaced.match(/https?:\\/\\/[^/]+\\//))thirdPartyScript=\ntrue;else if(stack.indexOf("trapProp")>=0&&stack.indexOf("trapChain")>=0)thirdPartyScript=true;else if(message.indexOf("redefine non-configurable")>=0)thirdPartyScript=true;var baseUrl=window["ytcfg"].get("EMERGENCY_BASE_URL","https://www.youtube.com/error_204?t=jserror&level=ERROR");var unsupported=message.indexOf("window.customElements is undefined")>=0;if(thirdPartyScript||unsupported)baseUrl=baseUrl.replace("level=ERROR","level=WARNING");var parts=[baseUrl];for(var key in values){var value=values[key];\nif(value)parts.push(key+"="+encodeURIComponent(value))}img.src=parts.join("&")};\n(function(){function _getExtendedNativePrototype(tag){var p=this._nativePrototypes[tag];if(!p){p=Object.create(this.getNativePrototype(tag));var p$=Object.getOwnPropertyNames(window["Polymer"].Base);for(var i=0,n=void 0;i<p$.length&&(n=p$[i]);i++)if(!window["Polymer"].BaseDescriptors[n])try{p[n]=window["Polymer"].Base[n]}catch(e){throw new Error("Error while copying property: "+n+". Tag is "+tag);}try{Object.defineProperties(p,window["Polymer"].BaseDescriptors)}catch(e$0){throw new Error("Polymer define property failed for "+\nObject.keys(p));}this._nativePrototypes[tag]=p}return p}function handlePolymerError(msg){window.onerror(msg,window.location.href,0,0,new Error(Array.prototype.join.call(arguments,",")))}var origPolymer=window["Polymer"];var newPolymer=function(config){if(!origPolymer._ytIntercepted&&window["Polymer"].Base){origPolymer._ytIntercepted=true;window["Polymer"].Base._getExtendedNativePrototype=_getExtendedNativePrototype;window["Polymer"].Base._error=handlePolymerError;window["Polymer"].Base._warn=handlePolymerError}return origPolymer.apply(this,\narguments)};var origDescriptor=Object.getOwnPropertyDescriptor(window,"Polymer");Object.defineProperty(windo ...
